# %%
import matplotlib.pyplot as plt
import numpy as np
from sympy import symbols, Eq, diff
import  random
x = symbols('x')

''' X_{n+1} = X_{n} - \frac{f(X_n)}{f'(X_n)}'''
def calc_error(punto_n, punto_v):
    e = abs((punto_n - punto_v) / punto_n)
    return e
    
def newton_raphson(funcion, error_g):
    g_func = eval(funcion)
    g_func_prima = g_func.diff(x)
    error = 1.0
    iteracion = 0
    X_val = random.uniform(1, 100)  
    X_new = 0
    while error >= error_g:
        X_new = X_val - ((g_func.evalf(subs={x: X_val}))/(g_func_prima.evalf(subs={x: X_val})))
        error = calc_error(X_new,X_val)
        iteracion +=1
        print(f'Iteración {iteracion}: {X_new}')
        X_val = X_new 
    return iteracion, X_new

iter, root = newton_raphson("x**x -100",10*10**(-5))
print(iter,root)
# Out:
# Iteración 1: 78.3803056988361
# Iteración 2: 78.1937932598069
# Iteración 3: 78.0071979069993
# Iteración 4: 77.8205193313498
# Iteración 5: 77.6337572217109
# Iteración 6: 77.4469112648309
# Iteración 7: 77.2599811453332
# Iteración 8: 77.0729665456958
# Iteración 9: 76.8858671462298
# Iteración 10: 76.6986826250583
# Iteración 11: 76.5114126580944
# Iteración 12: 76.3240569190198
# Iteración 13: 76.1366150792619
# Iteración 14: 75.9490868079719
# Iteración 15: 75.7614717720016
# Iteración 16: 75.5737696358806
# Iteración 17: 75.3859800617926
# Iteración 18: 75.1981027095517
# Iteración 19: 75.0101372365786
# Iteración 20: 74.8220832978762
# Iteración 21: 74.6339405460045
# Iteración 22: 74.4457086310562
# Iteración 23: 74.2573872006311
# Iteración 24: 74.0689758998102
# Iteración 25: 73.8804743711300
# Iteración 26: 73.6918822545559
# Iteración 27: 73.5031991874557
# Iteración 28: 73.3144248045721
# Iteración 29: 73.1255587379957
# Iteración 30: 72.9366006171368
# Iteración 31: 72.7475500686971
# Iteración 32: 72.5584067166417
# Iteración 33: 72.3691701821691
# Iteración 34: 72.1798400836827
# Iteración 35: 71.9904160367605
# Iteración 36: 71.8008976541247
# Iteración 37: 71.6112845456116
# Iteración 38: 71.4215763181398
# Iteración 39: 71.2317725756792
# Iteración 40: 71.0418729192188
# Iteración 41: 70.8518769467343
# Iteración 42: 70.6617842531550
# Iteración 43: 70.4715944303307
# Iteración 44: 70.2813070669977
# Iteración 45: 70.0909217487445
# Iteración 46: 69.9004380579768
# Iteración 47: 69.7098555738825
# Iteración 48: 69.5191738723956
# Iteración 49: 69.3283925261596
# Iteración 50: 69.1375111044911
# Iteración 51: 68.9465291733419
# Iteración 52: 68.7554462952614
# Iteración 53: 68.5642620293575
# Iteración 54: 68.3729759312579
# Iteración 55: 68.1815875530703
# Iteración 56: 67.9900964433417
# Iteración 57: 67.7985021470181
# Iteración 58: 67.6068042054025
# Iteración 59: 67.4150021561127
# Iteración 60: 67.2230955330389
# Iteración 61: 67.0310838662999
# Iteración 62: 66.8389666821988
# Iteración 63: 66.6467435031789
# Iteración 64: 66.4544138477775
# Iteración 65: 66.2619772305800
# Iteración 66: 66.0694331621729
# Iteración 67: 65.8767811490965
# Iteración 68: 65.6840206937959
# Iteración 69: 65.4911512945725
# Iteración 70: 65.2981724455337
# Iteración 71: 65.1050836365422
# Iteración 72: 64.9118843531648
# Iteración 73: 64.7185740766198
# Iteración 74: 64.5251522837240
# Iteración 75: 64.3316184468385
# Iteración 76: 64.1379720338142
# Iteración 77: 63.9442125079355
# Iteración 78: 63.7503393278642
# Iteración 79: 63.5563519475817
# Iteración 80: 63.3622498163304
# Iteración 81: 63.1680323785541
# Iteración 82: 62.9736990738379
# Iteración 83: 62.7792493368467
# Iteración 84: 62.5846825972624
# Iteración 85: 62.3899982797208
# Iteración 86: 62.1951958037465
# Iteración 87: 62.0002745836880
# Iteración 88: 61.8052340286503
# Iteración 89: 61.6100735424272
# Iteración 90: 61.4147925234324
# Iteración 91: 61.2193903646293
# Iteración 92: 61.0238664534594
# Iteración 93: 60.8282201717697
# Iteración 94: 60.6324508957390
# Iteración 95: 60.4365579958026
# Iteración 96: 60.2405408365757
# Iteración 97: 60.0443987767759
# Iteración 98: 59.8481311691440
# Iteración 99: 59.6517373603629
# Iteración 100: 59.4552166909765
# Iteración 101: 59.2585684953056
# Iteración 102: 59.0617921013632
# Iteración 103: 58.8648868307680
# Iteración 104: 58.6678519986567
# Iteración 105: 58.4706869135940
# Iteración 106: 58.2733908774815
# Iteración 107: 58.0759631854654
# Iteración 108: 57.8784031258410
# Iteración 109: 57.6807099799573
# Iteración 110: 57.4828830221183
# Iteración 111: 57.2849215194837
# Iteración 112: 57.0868247319666
# Iteración 113: 56.8885919121303
# Iteración 114: 56.6902223050827
# Iteración 115: 56.4917151483686
# Iteración 116: 56.2930696718601
# Iteración 117: 56.0942850976451
# Iteración 118: 55.8953606399135
# Iteración 119: 55.6962955048412
# Iteración 120: 55.4970888904717
# Iteración 121: 55.2977399865960
# Iteración 122: 55.0982479746296
# Iteración 123: 54.8986120274872
# Iteración 124: 54.6988313094550
# Iteración 125: 54.4989049760608
# Iteración 126: 54.2988321739411
# Iteración 127: 54.0986120407056
# Iteración 128: 53.8982437047993
# Iteración 129: 53.6977262853614
# Iteración 130: 53.4970588920819
# Iteración 131: 53.2962406250549
# Iteración 132: 53.0952705746288
# Iteración 133: 52.8941478212541
# Iteración 134: 52.6928714353271
# Iteración 135: 52.4914404770314
# Iteración 136: 52.2898539961753
# Iteración 137: 52.0881110320264
# Iteración 138: 51.8862106131423
# Iteración 139: 51.6841517571980
# Iteración 140: 51.4819334708095
# Iteración 141: 51.2795547493538
# Iteración 142: 51.0770145767851
# Iteración 143: 50.8743119254466
# Iteración 144: 50.6714457558792
# Iteración 145: 50.4684150166248
# Iteración 146: 50.2652186440263
# Iteración 147: 50.0618555620229
# Iteración 148: 49.8583246819407
# Iteración 149: 49.6546249022793
# Iteración 150: 49.4507551084926
# Iteración 151: 49.2467141727658
# Iteración 152: 49.0425009537868
# Iteración 153: 48.8381142965123
# Iteración 154: 48.6335530319294
# Iteración 155: 48.4288159768105
# Iteración 156: 48.2239019334641
# Iteración 157: 48.0188096894784
# Iteración 158: 47.8135380174597
# Iteración 159: 47.6080856747649
# Iteración 160: 47.4024514032275
# Iteración 161: 47.1966339288764
# Iteración 162: 46.9906319616496
# Iteración 163: 46.7844441950995
# Iteración 164: 46.5780693060924
# Iteración 165: 46.3715059544999
# Iteración 166: 46.1647527828830
# Iteración 167: 45.9578084161692
# Iteración 168: 45.7506714613203
# Iteración 169: 45.5433405069938
# Iteración 170: 45.3358141231940
# Iteración 171: 45.1280908609161
# Iteración 172: 44.9201692517804
# Iteración 173: 44.7120478076573
# Iteración 174: 44.5037250202833
# Iteración 175: 44.2951993608666
# Iteración 176: 44.0864692796833
# Iteración 177: 43.8775332056623
# Iteración 178: 43.6683895459602
# Iteración 179: 43.4590366855246
# Iteración 180: 43.2494729866462
# Iteración 181: 43.0396967884988
# Iteración 182: 42.8297064066672
# Iteración 183: 42.6195001326626
# Iteración 184: 42.4090762334247
# Iteración 185: 42.1984329508101
# Iteración 186: 41.9875685010676
# Iteración 187: 41.7764810742979
# Iteración 188: 41.5651688338994
# Iteración 189: 41.3536299159978
# Iteración 190: 41.1418624288605
# Iteración 191: 40.9298644522936
# Iteración 192: 40.7176340370227
# Iteración 193: 40.5051692040551
# Iteración 194: 40.2924679440246
# Iteración 195: 40.0795282165166
# Iteración 196: 39.8663479493739
# Iteración 197: 39.6529250379820
# Iteración 198: 39.4392573445334
# Iteración 199: 39.2253426972700
# Iteración 200: 39.0111788897024
# Iteración 201: 38.7967636798065
# Iteración 202: 38.5820947891949
# Iteración 203: 38.3671699022634
# Iteración 204: 38.1519866653111
# Iteración 205: 37.9365426856330
# Iteración 206: 37.7208355305846
# Iteración 207: 37.5048627266167
# Iteración 208: 37.2886217582801
# Iteración 209: 37.0721100671976
# Iteración 210: 36.8553250510042
# Iteración 211: 36.6382640622515
# Iteración 212: 36.4209244072775
# Iteración 213: 36.2033033450383
# Iteración 214: 35.9853980859022
# Iteración 215: 35.7672057904016
# Iteración 216: 35.5487235679451
# Iteración 217: 35.3299484754839
# Iteración 218: 35.1108775161339
# Iteración 219: 34.8915076377495
# Iteración 220: 34.6718357314482
# Iteración 221: 34.4518586300832
# Iteración 222: 34.2315731066620
# Iteración 223: 34.0109758727093
# Iteración 224: 33.7900635765697
# Iteración 225: 33.5688328016506
# Iteración 226: 33.3472800645990
# Iteración 227: 33.1254018134131
# Iteración 228: 32.9031944254820
# Iteración 229: 32.6806542055528
# Iteración 230: 32.4577773836205
# Iteración 231: 32.2345601127375
# Iteración 232: 32.0109984667388
# Iteración 233: 31.7870884378785
# Iteración 234: 31.5628259343740
# Iteración 235: 31.3382067778528
# Iteración 236: 31.1132267006977
# Iteración 237: 30.8878813432846
# Iteración 238: 30.6621662511081
# Iteración 239: 30.4360768717894
# Iteración 240: 30.2096085519592
# Iteración 241: 29.9827565340115
# Iteración 242: 29.7555159527188
# Iteración 243: 29.5278818317039
# Iteración 244: 29.2998490797586
# Iteración 245: 29.0714124870034
# Iteración 246: 28.8425667208765
# Iteración 247: 28.6133063219464
# Iteración 248: 28.3836256995349
# Iteración 249: 28.1535191271426
# Iteración 250: 27.9229807376638
# Iteración 251: 27.6920045183805
# Iteración 252: 27.4605843057207
# Iteración 253: 27.2287137797698
# Iteración 254: 26.9963864585178
# Iteración 255: 26.7635956918290
# Iteración 256: 26.5303346551160
# Iteración 257: 26.2965963426999
# Iteración 258: 26.0623735608386
# Iteración 259: 25.8276589204012
# Iteración 260: 25.5924448291668
# Iteración 261: 25.3567234837231
# Iteración 262: 25.1204868609406
# Iteración 263: 24.8837267089914
# Iteración 264: 24.6464345378864
# Iteración 265: 24.4086016094955
# Iteración 266: 24.1702189270165
# Iteración 267: 23.9312772238558
# Iteración 268: 23.6917669518787
# Iteración 269: 23.4516782689846
# Iteración 270: 23.2110010259603
# Iteración 271: 22.9697247525570
# Iteración 272: 22.7278386427354
# Iteración 273: 22.4853315390162
# Iteración 274: 22.2421919158683
# Iteración 275: 21.9984078620606
# Iteración 276: 21.7539670618980
# Iteración 277: 21.5088567752515
# Iteración 278: 21.2630638162866
# Iteración 279: 21.0165745307854
# Iteración 280: 20.7693747719426
# Iteración 281: 20.5214498745114
# Iteración 282: 20.2727846271552
# Iteración 283: 20.0233632428515
# Iteración 284: 19.7731693271753
# Iteración 285: 19.5221858442725
# Iteración 286: 19.2703950803124
# Iteración 287: 19.0177786041863
# Iteración 288: 18.7643172251912
# Iteración 289: 18.5099909474102
# Iteración 290: 18.2547789204656
# Iteración 291: 17.9986593862846
# Iteración 292: 17.7416096214712
# Iteración 293: 17.4836058748310
# Iteración 294: 17.2246232995379
# Iteración 295: 16.9646358793639
# Iteración 296: 16.7036163483226
# Iteración 297: 16.4415361029869
# Iteración 298: 16.1783651066410
# Iteración 299: 15.9140717843136
# Iteración 300: 15.6486229075988
# Iteración 301: 15.3819834680179
# Iteración 302: 15.1141165374853
# Iteración 303: 14.8449831142271
# Iteración 304: 14.5745419522409
# Iteración 305: 14.3027493720814
# Iteración 306: 14.0295590503942
# Iteración 307: 13.7549217851852
# Iteración 308: 13.4787852332936
# Iteración 309: 13.2010936159121
# Iteración 310: 12.9217873872339
# Iteración 311: 12.6408028603881
# Iteración 312: 12.3580717836911
# Iteración 313: 12.0735208588490
# Iteración 314: 11.7870711910280
# Iteración 315: 11.4986376585555
# Iteración 316: 11.2081281873281
# Iteración 317: 10.9154429115941
# Iteración 318: 10.6204731984525
# Iteración 319: 10.3231005078553
# Iteración 320: 10.0231950527337
# Iteración 321: 9.72061421455650
# Iteración 322: 9.41520065749365
# Iteración 323: 9.10678006859970
# Iteración 324: 8.79515843134266
# Iteración 325: 8.48011871556844
# Iteración 326: 8.16141684215954
# Iteración 327: 7.83877676943033
# Iteración 328: 7.51188459635597
# Iteración 329: 7.18038182057365
# Iteración 330: 6.84385871502127
# Iteración 331: 6.50185128959391
# Iteración 332: 6.15385253346940
# Iteración 333: 5.79936903061924
# Iteración 334: 5.43811064915206
# Iteración 335: 5.07055453853147
# Iteración 336: 4.69951867473694
# Iteración 337: 4.33423328807378
# Iteración 338: 3.99917736014739
# Iteración 339: 3.74411246485702
# Iteración 340: 3.62057661477236
# Iteración 341: 3.59792553699750
# Iteración 342: 3.59728551604642
# Iteración 343: 3.59728502354071
# 343 3.59728502354071

# %%
f = lambda x: eval("x".replace("x", str(x)))
f_p = "x**2".diff(x)
print(f_p)
f(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 f = lambda x: eval("x".replace("x", str(x)))
# ----> 2 f_p = "x**2".diff(x)
#       3 print(f_p)
#       4 f(10)
#
# AttributeError: 'str' object has no attribute 'diff'

# %%
from sympy import symbols, Eq, diff, evalf
x = symbols('x')
func = "x*x"
y = eval(func)
yprima = y.diff(x)
yprima.evalf(subs={x: 2.4})
# Out:
# 4.80000000000000

# %%
import sys
print(sys.float_info.max - sys.float_info.min)
# Out:
# 1.7976931348623157e+308

# %%
from sympy import symbols

x = symbols('x')

def bisection_method(funcion, error):
    funcion = eval(funcion)
    a = -100.0
    b = 100.0
    iterations = 0
    y_value = 0

    while (b - a) / 2 >= error:
        c = (b + a) / 2.0
        y_value = c
        if funcion.evalf(subs={x: c}) >= 0:
            b = c
        else:
            a = c
        iterations += 1
        

    return iterations, y_value

iteraciones, root = bisection_method("x**x-100", 10 * 10 ** (-4))
print(f'Número de iteraciones: {iteraciones}')
print(f'Raíz aproximada: {root}')
# Out:
# Número de iteraciones: 17
# Raíz aproximada: 3.59649658203125

# %%
def secante(funcion, error):
    funcion = eval(funcion)
    solp1 = 1.0
    solm1 = 3.4
    e = 1
    iterations = 0
    y_value = 0

    while abs(solp1 - solm1) / 2 >= error:
        iterations += 1
        a = solp1
        solp1 = solp1 - (solp1 - solm1) / (funcion.evalf(subs={x: solp1}) - funcion.evalf(subs={x: solm1})) * funcion.evalf(subs={x: solp1})
        solm1 = a
        #e = abs(solp1 - solm1) / 2
        print(solp1)
        y_value = solp1

    return iterations, y_value

iteraciones, root = secante("x**x-100", 10 * 10 ** (-10))
print(f'Número de iteraciones: {iteraciones}')
print(f'Raíz aproximada: {root}')
# Out:
# 4.76395212171275
# 1.21964991030288
# 1.42594272071751
# 54.1780007843564
# 1.42594272071751
# 1.42594272071751
# Número de iteraciones: 6
# Raíz aproximada: 1.42594272071751

# %%
from sympy import symbols
import  random

x = symbols('x')

def secante(funcion, error):
    funcion = eval(funcion)
    solp1 = 3
    solm1 = 10
    iterations = 0
    e = 1

    while e >= error:
        iterations += 1
        a = solp1
        solp1 = solp1 - (solp1 - solm1) / (funcion.evalf(subs={x: solp1}) - funcion.evalf(subs={x: solm1})) * funcion.evalf(subs={x: solp1})
        solm1 = a
        e = abs(solp1 - solm1) / solp1
        print(e)
        print(f'Iteración {iterations}: {solp1}')

    return iterations, solp1

iteraciones, root = secante("x**x - 100",  10 * 10 ** (-9))
print(f'Número de iteraciones: {iteraciones}')
print(f'Raíz aproximada: {root}')
# Out:
# 0
# Iteración 1: 30.0000000000000
# Número de iteraciones: 1
# Raíz aproximada: 30.0000000000000

# %%
import random
from sympy import symbols

x = symbols('x')

def secante(funcion, error):
    funcion = eval(funcion)
    solp1 = 0
    solm1 = random.uniform(1, 10)
    iterations = 0

    while abs(solp1 - solm1) / 2 >= error:
        iterations += 1
        a = solp1
        solp1 = solp1 - (solp1 - solm1) / (funcion.evalf(subs={x: solp1}) - funcion.evalf(subs={x: solm1})) * funcion.evalf(subs={x: solp1})
        solm1 = a
        print(f'Iteración {iterations}: {solp1}')

    return iterations, solp1

iteraciones, root = secante("x**x - 100", 10 * 10 ** (-9))
print(f'Número de iteraciones: {iteraciones}')
print(f'Raíz aproximada: {root}')
# Out:
# Iteración 1: 389.402593896087
# Iteración 2: 0
# Iteración 3: 7.55103467945563E-1005
# Número de iteraciones: 3
# Raíz aproximada: 7.55103467945563E-1005

# %%
def calc_error(punto_n, punto_v):
    e = abs((punto_n - punto_v) / punto_n)
    return e


def newton_raphson(funcion, error_g):
    g_func = eval(funcion)
    g_func_prima = g_func.diff(x)
    error = 1.0
    iteracion = 0
    X_val = random.uniform(1, 100)
    X_new = 0
    while error >= error_g:
        X_new = X_val - ((g_func.evalf(subs={x: X_val})) / (g_func_prima.evalf(subs={x: X_val})))
        error = calc_error(X_new, X_val)
        iteracion += 1
        print(f'Iteración {iteracion}: {X_new}')
        X_val = X_new
    return iteracion, X_new
iteraciones, root = newton_raphson("x**x - 100", 10 * 10 ** (-9))
print(f'Número de iteraciones: {iteraciones}')
print(f'Raíz aproximada: {root}')
# Out:
# Iteración 1: 9.69720689646382
# Iteración 2: 9.39156829058976
# Iteración 3: 9.08290845621404
# Iteración 4: 8.77103173118224
# Iteración 5: 8.45571915680327
# Iteración 6: 8.13672438027067
# Iteración 7: 7.81376866773989
# Iteración 8: 7.48653493216879
# Iteración 9: 7.15466094887556
# Iteración 10: 6.81773283375055
# Iteración 11: 6.47528257786857
# Iteración 12: 6.12680126764433
# Iteración 13: 5.77180169662774
# Iteración 14: 5.41002526431732
# Iteración 15: 5.04205358383443
# Iteración 16: 4.67100697659585
# Iteración 17: 4.30690309465086
# Iteración 18: 3.97589901706750
# Iteración 19: 3.72958848096495
# Iteración 20: 3.61639162268907
# Iteración 21: 3.59771736606138
# Iteración 22: 3.59728524796867
# Iteración 23: 3.59728502354048
# Iteración 24: 3.59728502354042
# Número de iteraciones: 24
# Raíz aproximada: 3.59728502354042
